# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("ipl2020.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             332 non-null    int64
#  1   List Sr. No.           332 non-null    int64
#  2   Set No.                332 non-null    int64
#  3   2020 Set               332 non-null    object
#  4   First Name             332 non-null    object
#  5   Surname                332 non-null    object
#  6   Country                332 non-null    object
#  7   State Association      332 non-null    object
#  8   DOB                    332 non-null    object
#  9   Age                    332 non-null    int64
#  10  Specialism             332 non-null    object
#  11  Unnamed: 10            332 non-null    object
#  12  Unnamed: 11            332 non-null    object
#  13  Test caps              71 non-null     float64
#  14  ODI
# ...

# %%
df.head(5)
# Out:
#    Unnamed: 0  List Sr. No.  Set No. 2020 Set  First Name Surname    Country  \
# 0           0             1        1      BA1       Aaron   Finch  Australia
# 1           1             2        1      BA1       Chris    Lynn  Australia
# 2           2             3        1      BA1        Eoin  Morgan    England
# 3           3             4        1      BA1  Cheteshwar  Pujara      India
# 4           4             5        1      BA1       Jason     Roy    England
#
#   State Association         DOB  Age  ... Test caps ODI\ncaps T20\ncaps   IPL  \
# 0                CA  1986-11-17   33  ...       5.0     119.0      58.0  75.0
# 1                CA  1990-04-10   29  ...       NaN       4.0      18.0  41.0
# 2               ECB  1986-09-10   33  ...      16.0     233.0      86.0  52.0
# 3               SCA  1988-01-25   32  ...      75.0       5.0       NaN  30.0
# 4               ECB  1990-07-21   29  ...       5.0      84.0      32.0   8.0
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'List Sr. No.', 'Set No.', '2020 Set', 'First Name',
#        'Surname', 'Country', 'State Association', 'DOB', 'Age', 'Specialism',
#        'Unnamed: 10', 'Unnamed: 11', 'Test caps', 'ODI\ncaps', 'T20\ncaps',
#        'IPL', 'Previous IPLTeam(s)', '2019\nTeam', '2019\nIPL', 'C/U/A',
#        'Reserve\nPrice Rs Lakh', 'Surname.1'],
#       dtype='object')

# %%
df.drop(["2019\nTeam","2019\nIPL","C/U/A"],axis=1,inplace=True)

# %%
df.drop(['Test caps','Unnamed: 10','ODI\ncaps',"T20\ncaps","Surname.1",],axis=1,inplace=True)

# %%
df.head(4)
# Out:
#    Unnamed: 0  List Sr. No.  Set No. 2020 Set  First Name Surname    Country  \
# 0           0             1        1      BA1       Aaron   Finch  Australia
# 1           1             2        1      BA1       Chris    Lynn  Australia
# 2           2             3        1      BA1        Eoin  Morgan    England
# 3           3             4        1      BA1  Cheteshwar  Pujara      India
#
#   State Association         DOB  Age Specialism             Unnamed: 11   IPL  \
# 0                CA  1986-11-17   33    BATSMAN  LEFT ARM Slow Orthodox  75.0
# 1                CA  1990-04-10   29    BATSMAN  LEFT ARM Slow Orthodox  41.0
# 2               ECB  1986-09-10   33    BATSMAN        RIGHT ARM Medium  52.0
# 3               SCA  1988-01-25   32    BATSMAN     RIGHT ARM Leg Break  30.0
#
#               Previous IPLTeam(s)  Reserve\nPrice Rs Lakh
# 0  RR, DD, PWI, SRH, MI, GL, KXIP                     100
# 1                        DCH, KKR                     200
# ...

# %%
df.columns=[x.upper() for x in df.columns]

# %%
df
# Out:
#      UNNAMED: 0  LIST SR. NO.  SET NO. 2020 SET  FIRST NAME     SURNAME  \
# 0             0             1        1      BA1       Aaron       Finch
# 1             1             2        1      BA1       Chris        Lynn
# 2             2             3        1      BA1        Eoin      Morgan
# 3             3             4        1      BA1  Cheteshwar      Pujara
# 4             4             5        1      BA1       Jason         Roy
# ..          ...           ...      ...      ...         ...         ...
# 327         327           328       44     UAL8       Shaik      Ismail
# 328         328           329       44     UAL8        Will       Jacks
# 329         329           330       44     UAL8        Jack  Prestwidge
# 330         330           331       44     UAL8        Yash      Rathod
# 331         331           332       44     UAL8    Pratyush       Singh
#
#        COUNTRY STATE ASSOCIATION         DOB  AGE   SPECIALISM  \
# ...

# %%
df.columns
# Out:
# Index(['UNNAMED: 0', 'LIST SR. NO.', 'SET NO.', '2020 SET', 'FIRST NAME',
#        'SURNAME', 'COUNTRY', 'STATE ASSOCIATION', 'DOB', 'AGE', 'SPECIALISM',
#        'UNNAMED: 11', 'IPL', 'PREVIOUS IPLTEAM(S)', 'RESERVE\nPRICE RS LAKH'],
#       dtype='object')

# %%
df.columns=['index1', 'LIST SR. NO.', 'SET NO.', '2020 SET', 'FIRST NAME',
       'SURNAME', 'COUNTRY', 'STATE ASSOCIATION', 'DOB', 'AGE', 'SPECIALISM',
       'BATTING_POSITIONS', 'IPL', 'PREVIOUS IPLTEAM(S)', 'RESERVE\nPRICE RS LAKH']

# %%
df
# Out:
#      index1  LIST SR. NO.  SET NO. 2020 SET  FIRST NAME     SURNAME  \
# 0         0             1        1      BA1       Aaron       Finch
# 1         1             2        1      BA1       Chris        Lynn
# 2         2             3        1      BA1        Eoin      Morgan
# 3         3             4        1      BA1  Cheteshwar      Pujara
# 4         4             5        1      BA1       Jason         Roy
# ..      ...           ...      ...      ...         ...         ...
# 327     327           328       44     UAL8       Shaik      Ismail
# 328     328           329       44     UAL8        Will       Jacks
# 329     329           330       44     UAL8        Jack  Prestwidge
# 330     330           331       44     UAL8        Yash      Rathod
# 331     331           332       44     UAL8    Pratyush       Singh
#
#        COUNTRY STATE ASSOCIATION         DOB  AGE   SPECIALISM  \
# 0    Australia                CA  1986-11-17   33      BATSMAN
# ...

# %%
base_price=df.sort_values(by="RESERVE\nPRICE RS LAKH",ascending=False)

# %%
base_price
# Out:
#      index1  LIST SR. NO.  SET NO. 2020 SET FIRST NAME    SURNAME  \
# 1         1             2        1      BA1      Chris       Lynn
# 8         8             9        2      AL1        Pat    Cummins
# 25       25            26        4      FA1       Dale      Steyn
# 78       78            79       13      FA2       Josh  Hazlewood
# 248     248           249       35      AL5     Angelo    Mathews
# ..      ...           ...      ...      ...        ...        ...
# 168     168           169       25     UAL3      Sumit      Kumar
# 169     169           170       25     UAL3     Vishal    Kushwah
# 170     170           171       25     UAL3   Akshdeep       Nath
# 171     171           172       26     UWK3        Avi      Barot
# 331     331           332       44     UAL8   Pratyush      Singh
#
#           COUNTRY STATE ASSOCIATION         DOB  AGE    SPECIALISM  \
# 1       Australia                CA  1990-04-10   29       BATSMAN
# ...

# %%
final=base_price.drop(['index1','LIST SR. NO.'],axis=1)

# %%
final
# Out:
#      SET NO. 2020 SET FIRST NAME    SURNAME       COUNTRY STATE ASSOCIATION  \
# 1          1      BA1      Chris       Lynn     Australia                CA
# 8          2      AL1        Pat    Cummins     Australia                CA
# 25         4      FA1       Dale      Steyn  South Africa               CSA
# 78        13      FA2       Josh  Hazlewood     Australia                CA
# 248       35      AL5     Angelo    Mathews     Sri Lanka               SLC
# ..       ...      ...        ...        ...           ...               ...
# 168       25     UAL3      Sumit      Kumar         India               HCA
# 169       25     UAL3     Vishal    Kushwah         India            CSCSCA
# 170       25     UAL3   Akshdeep       Nath         India              UPCA
# 171       26     UWK3        Avi      Barot         India               SCA
# 331       44     UAL8   Pratyush      Singh         India               TCA
#
# ...

# %%
final.reset_index()
# Out:
#      index  SET NO. 2020 SET FIRST NAME    SURNAME       COUNTRY  \
# 0        1        1      BA1      Chris       Lynn     Australia
# 1        8        2      AL1        Pat    Cummins     Australia
# 2       25        4      FA1       Dale      Steyn  South Africa
# 3       78       13      FA2       Josh  Hazlewood     Australia
# 4      248       35      AL5     Angelo    Mathews     Sri Lanka
# ..     ...      ...      ...        ...        ...           ...
# 327    168       25     UAL3      Sumit      Kumar         India
# 328    169       25     UAL3     Vishal    Kushwah         India
# 329    170       25     UAL3   Akshdeep       Nath         India
# 330    171       26     UWK3        Avi      Barot         India
# 331    331       44     UAL8   Pratyush      Singh         India
#
#     STATE ASSOCIATION         DOB  AGE    SPECIALISM       BATTING_POSITIONS  \
# 0                  CA  1990-04-10   29       BATSMAN  LEFT ARM Slow Orthodox
# ...

# %% [markdown]
# ## NAME OF ALL PLAYERS

# %%
# for loop to manipulate the data
for index,row in final.iterrows():
    print(index,row['FIRST NAME'])
# Out:
# 1 Chris
# 8 Pat
# 25 Dale
# 78 Josh
# 248 Angelo
# 11 Glenn
# 73 Mitchell
# 135 David
# 5 Robin
# 210 Kyle
# 125 Shaun
# 12 Chris
# 14 Chris
# 32 Adam
# 4 Jason
# 146 Kane
# 2 Eoin
# 215 James
# 63 Martin
# 207 D'Arcy
# 204 Moises
# 201 Ashton
# 121 Tom
# 66 Evin
# 74 Colin
# 77 Marcus
# 289 Thisara
# 122 Alex
# 126 Rilee
# 129 Tom
# 216 Liam
# 0 Aaron
# 82 Mustafizur
# 28 Piyush
# 22 Nathan
# 24 Tim
# 9 Sam
# 26 Andrew
# 13 Yusuf
# 27 Jaydev
# 252 Ashton
# 208 David
# 20 Mushfiqur
# 67 David
# 131 Chris
# 130 Jason
# 199 Lendl
# 142 Sean
# 128 Corey
# 10 Colin
# 286 Dan
# 254 Saqib
# 247 Mohammad
# 30 Ish
# 212 Marchant
# 71 Ben
# 16 Shai
# 246 Dimuth
# 133 Rovman
# 132 Daryl
# 123 Janneman
# 17 Heinrich
# 124 Aiden
# 244 Ravi
# 245 Wanindu
# 249 Wiaan
# 134 Isuru
# 288 Jeevan
# 15 Alex
# 127 Fabian
# 287 Anaru
# 7 Stuart
# 139 Glenn
# 6 Hanuma
# 136 Ben
# 258 Kesrick
# 257 Blair
# 256 Nuwan
# 255 Obed
# 253 Dushmanta
# 251 Jon Jon
# 250 Dasun
# 153 Tabraiz
# 152 Waqar
# 151 Khary
# ...

# %%
final['FIRST NAME'].apply(len)
# Out:
# 1      5
# 8      3
# 25     4
# 78     4
# 248    6
#       ..
# 168    5
# 169    6
# 170    8
# 171    3
# 331    8
# Name: FIRST NAME, Length: 332, dtype: int64

# %%
final['FIRST NAME'].apply(lambda x:x.capititalize())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-1f039ecb732f> in <module>
# ----> 1 final['FIRST NAME'].apply(lambda x:x.capititalize())
#
# c:\users\sanket\appdata\local\programs\python\python38\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-27-1f039ecb732f> in <lambda>(x)
# ----> 1 final['FIRST NAME'].apply(lambda x:x.capititalize())
#
# AttributeError: 'str' object has no attribute 'capititalize'
