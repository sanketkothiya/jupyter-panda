# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('ipl20.xlsx')

# %%
df
# Out:
#      List Sr. No.  Set No. 2020 Set  First Name     Surname    Country  \
# 0               1        1      BA1       Aaron       Finch  Australia
# 1               2        1      BA1       Chris        Lynn  Australia
# 2               3        1      BA1        Eoin      Morgan    England
# 3               4        1      BA1  Cheteshwar      Pujara      India
# 4               5        1      BA1       Jason         Roy    England
# ..            ...      ...      ...         ...         ...        ...
# 327           328       44     UAL8       Shaik      Ismail      India
# 328           329       44     UAL8        Will       Jacks    England
# 329           330       44     UAL8        Jack  Prestwidge  Australia
# 330           331       44     UAL8        Yash      Rathod      India
# 331           332       44     UAL8    Pratyush       Singh      India
#
#     State Association        DOB  Age   Specialism  ... Test caps ODI\ncaps  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   List Sr. No.           332 non-null    int64
#  1   Set No.                332 non-null    int64
#  2   2020 Set               332 non-null    object
#  3   First Name             332 non-null    object
#  4   Surname                332 non-null    object
#  5   Country                332 non-null    object
#  6   State Association      332 non-null    object
#  7   DOB                    332 non-null    datetime64[ns]
#  8   Age                    332 non-null    int64
#  9   Specialism             332 non-null    object
#  10  Unnamed: 10            332 non-null    object
#  11  Unnamed: 11            332 non-null    object
#  12  Test caps              71 non-null     float64
#  13  ODI
# caps               116 non-null    float64
#  14  T20
# ...

# %%
df.columns
# Out:
# Index(['List Sr. No.', 'Set No.', '2020 Set', 'First Name', 'Surname',
#        'Country', 'State Association', 'DOB', 'Age', 'Specialism',
#        'Unnamed: 10', 'Unnamed: 11', 'Test caps', 'ODI\ncaps', 'T20\ncaps',
#        'IPL', 'Previous IPLTeam(s)', '2019\nTeam', '2019\nIPL', 'C/U/A',
#        'Reserve\nPrice Rs Lakh', 'Surname.1'],
#       dtype='object')

# %%
df.head(4)
# Out:
#    List Sr. No.  Set No. 2020 Set  First Name Surname    Country  \
# 0             1        1      BA1       Aaron   Finch  Australia
# 1             2        1      BA1       Chris    Lynn  Australia
# 2             3        1      BA1        Eoin  Morgan    England
# 3             4        1      BA1  Cheteshwar  Pujara      India
#
#   State Association        DOB  Age Specialism  ... Test caps ODI\ncaps  \
# 0                CA 1986-11-17   33    BATSMAN  ...       5.0     119.0
# 1                CA 1990-04-10   29    BATSMAN  ...       NaN       4.0
# 2               ECB 1986-09-10   33    BATSMAN  ...      16.0     233.0
# 3               SCA 1988-01-25   32    BATSMAN  ...      75.0       5.0
#
#    T20\ncaps   IPL             Previous IPLTeam(s)  2019\nTeam 2019\nIPL  \
# 0       58.0  75.0  RR, DD, PWI, SRH, MI, GL, KXIP         NaN       NaN
# 1       18.0  41.0                        DCH, KKR         KKR      13.0
# ...

# %%
df.to_csv('ipl2020.csv')

# %%
s1=pd.read_csv("ipl2020.csv")

# %%
s1
# Out:
#      Unnamed: 0  List Sr. No.  Set No. 2020 Set  First Name     Surname  \
# 0             0             1        1      BA1       Aaron       Finch
# 1             1             2        1      BA1       Chris        Lynn
# 2             2             3        1      BA1        Eoin      Morgan
# 3             3             4        1      BA1  Cheteshwar      Pujara
# 4             4             5        1      BA1       Jason         Roy
# ..          ...           ...      ...      ...         ...         ...
# 327         327           328       44     UAL8       Shaik      Ismail
# 328         328           329       44     UAL8        Will       Jacks
# 329         329           330       44     UAL8        Jack  Prestwidge
# 330         330           331       44     UAL8        Yash      Rathod
# 331         331           332       44     UAL8    Pratyush       Singh
#
#        Country State Association         DOB  Age  ... Test caps ODI\ncaps  \
# ...

# %%
p1=s1.drop(['Test caps','Unnamed: 10','ODI\ncaps',"T20\ncaps","Surname.1",],axis=1)

# %%
p1
# Out:
#      Unnamed: 0  List Sr. No.  Set No. 2020 Set  First Name     Surname  \
# 0             0             1        1      BA1       Aaron       Finch
# 1             1             2        1      BA1       Chris        Lynn
# 2             2             3        1      BA1        Eoin      Morgan
# 3             3             4        1      BA1  Cheteshwar      Pujara
# 4             4             5        1      BA1       Jason         Roy
# ..          ...           ...      ...      ...         ...         ...
# 327         327           328       44     UAL8       Shaik      Ismail
# 328         328           329       44     UAL8        Will       Jacks
# 329         329           330       44     UAL8        Jack  Prestwidge
# 330         330           331       44     UAL8        Yash      Rathod
# 331         331           332       44     UAL8    Pratyush       Singh
#
#        Country State Association         DOB  Age   Specialism  \
# ...

# %%
p1.reset_index(drop=True,)
# Out:
#      Unnamed: 0  List Sr. No.  Set No. 2020 Set  First Name     Surname  \
# 0             0             1        1      BA1       Aaron       Finch
# 1             1             2        1      BA1       Chris        Lynn
# 2             2             3        1      BA1        Eoin      Morgan
# 3             3             4        1      BA1  Cheteshwar      Pujara
# 4             4             5        1      BA1       Jason         Roy
# ..          ...           ...      ...      ...         ...         ...
# 327         327           328       44     UAL8       Shaik      Ismail
# 328         328           329       44     UAL8        Will       Jacks
# 329         329           330       44     UAL8        Jack  Prestwidge
# 330         330           331       44     UAL8        Yash      Rathod
# 331         331           332       44     UAL8    Pratyush       Singh
#
#        Country State Association         DOB  Age   Specialism  \
# ...

# %%
p1.sort_values('Reserve\nPrice Rs Lakh',ascending=False)
# Out:
#      Unnamed: 0  List Sr. No.  Set No. 2020 Set First Name    Surname  \
# 1             1             2        1      BA1      Chris       Lynn
# 8             8             9        2      AL1        Pat    Cummins
# 25           25            26        4      FA1       Dale      Steyn
# 78           78            79       13      FA2       Josh  Hazlewood
# 248         248           249       35      AL5     Angelo    Mathews
# ..          ...           ...      ...      ...        ...        ...
# 168         168           169       25     UAL3      Sumit      Kumar
# 169         169           170       25     UAL3     Vishal    Kushwah
# 170         170           171       25     UAL3   Akshdeep       Nath
# 171         171           172       26     UWK3        Avi      Barot
# 331         331           332       44     UAL8   Pratyush      Singh
#
#           Country State Association         DOB  Age    Specialism  \
# ...

# %%
p1.reset_index(drop=True)
# Out:
#      Unnamed: 0  List Sr. No.  Set No. 2020 Set  First Name     Surname  \
# 0             0             1        1      BA1       Aaron       Finch
# 1             1             2        1      BA1       Chris        Lynn
# 2             2             3        1      BA1        Eoin      Morgan
# 3             3             4        1      BA1  Cheteshwar      Pujara
# 4             4             5        1      BA1       Jason         Roy
# ..          ...           ...      ...      ...         ...         ...
# 327         327           328       44     UAL8       Shaik      Ismail
# 328         328           329       44     UAL8        Will       Jacks
# 329         329           330       44     UAL8        Jack  Prestwidge
# 330         330           331       44     UAL8        Yash      Rathod
# 331         331           332       44     UAL8    Pratyush       Singh
#
#        Country State Association         DOB  Age   Specialism  \
# ...

# %%
p1.reset_index(drop=True, inplace=True)

# %%
p1
# Out:
#      Unnamed: 0  List Sr. No.  Set No. 2020 Set  First Name     Surname  \
# 0             0             1        1      BA1       Aaron       Finch
# 1             1             2        1      BA1       Chris        Lynn
# 2             2             3        1      BA1        Eoin      Morgan
# 3             3             4        1      BA1  Cheteshwar      Pujara
# 4             4             5        1      BA1       Jason         Roy
# ..          ...           ...      ...      ...         ...         ...
# 327         327           328       44     UAL8       Shaik      Ismail
# 328         328           329       44     UAL8        Will       Jacks
# 329         329           330       44     UAL8        Jack  Prestwidge
# 330         330           331       44     UAL8        Yash      Rathod
# 331         331           332       44     UAL8    Pratyush       Singh
#
#        Country State Association         DOB  Age   Specialism  \
# ...

# %%
p1.drop(['Unnamed: 0'],axis=1)
# Out:
#      List Sr. No.  Set No. 2020 Set  First Name     Surname    Country  \
# 0               1        1      BA1       Aaron       Finch  Australia
# 1               2        1      BA1       Chris        Lynn  Australia
# 2               3        1      BA1        Eoin      Morgan    England
# 3               4        1      BA1  Cheteshwar      Pujara      India
# 4               5        1      BA1       Jason         Roy    England
# ..            ...      ...      ...         ...         ...        ...
# 327           328       44     UAL8       Shaik      Ismail      India
# 328           329       44     UAL8        Will       Jacks    England
# 329           330       44     UAL8        Jack  Prestwidge  Australia
# 330           331       44     UAL8        Yash      Rathod      India
# 331           332       44     UAL8    Pratyush       Singh      India
#
#     State Association         DOB  Age   Specialism             Unnamed: 11  \
# ...

# %%
sort=s1.sort_values('Reserve\nPrice Rs Lakh',ascending=False)

# %%
sort
# Out:
#      Unnamed: 0  List Sr. No.  Set No. 2020 Set First Name    Surname  \
# 1             1             2        1      BA1      Chris       Lynn
# 8             8             9        2      AL1        Pat    Cummins
# 25           25            26        4      FA1       Dale      Steyn
# 78           78            79       13      FA2       Josh  Hazlewood
# 248         248           249       35      AL5     Angelo    Mathews
# ..          ...           ...      ...      ...        ...        ...
# 168         168           169       25     UAL3      Sumit      Kumar
# 169         169           170       25     UAL3     Vishal    Kushwah
# 170         170           171       25     UAL3   Akshdeep       Nath
# 171         171           172       26     UWK3        Avi      Barot
# 331         331           332       44     UAL8   Pratyush      Singh
#
#           Country State Association         DOB  Age  ... Test caps ODI\ncaps  \
# ...

# %%
sort.reset_index(drop=True, inplace=True)

# %%
sort
# Out:
#      Unnamed: 0  List Sr. No.  Set No. 2020 Set First Name    Surname  \
# 0             1             2        1      BA1      Chris       Lynn
# 1             8             9        2      AL1        Pat    Cummins
# 2            25            26        4      FA1       Dale      Steyn
# 3            78            79       13      FA2       Josh  Hazlewood
# 4           248           249       35      AL5     Angelo    Mathews
# ..          ...           ...      ...      ...        ...        ...
# 327         168           169       25     UAL3      Sumit      Kumar
# 328         169           170       25     UAL3     Vishal    Kushwah
# 329         170           171       25     UAL3   Akshdeep       Nath
# 330         171           172       26     UWK3        Avi      Barot
# 331         331           332       44     UAL8   Pratyush      Singh
#
#           Country State Association         DOB  Age  ... Test caps ODI\ncaps  \
# ...

# %%
final=sort.drop(["Unnamed: 11","List Sr. No.","C/U/A"],axis=1)

# %%
final
# Out:
#      Unnamed: 0  Set No. 2020 Set First Name    Surname       Country  \
# 0             1        1      BA1      Chris       Lynn     Australia
# 1             8        2      AL1        Pat    Cummins     Australia
# 2            25        4      FA1       Dale      Steyn  South Africa
# 3            78       13      FA2       Josh  Hazlewood     Australia
# 4           248       35      AL5     Angelo    Mathews     Sri Lanka
# ..          ...      ...      ...        ...        ...           ...
# 327         168       25     UAL3      Sumit      Kumar         India
# 328         169       25     UAL3     Vishal    Kushwah         India
# 329         170       25     UAL3   Akshdeep       Nath         India
# 330         171       26     UWK3        Avi      Barot         India
# 331         331       44     UAL8   Pratyush      Singh         India
#
#     State Association         DOB  Age    Specialism Unnamed: 10  Test caps  \
# ...

# %%
# for loop to manipulate the data
for index,row in final.iterrows():
    print(index,row['First Name'])
# Out:
# 0 Chris
# 1 Pat
# 2 Dale
# 3 Josh
# 4 Angelo
# 5 Glenn
# 6 Mitchell
# 7 David
# 8 Robin
# 9 Kyle
# 10 Shaun
# 11 Chris
# 12 Chris
# 13 Adam
# 14 Jason
# 15 Kane
# 16 Eoin
# 17 James
# 18 Martin
# 19 D'Arcy
# 20 Moises
# 21 Ashton
# 22 Tom
# 23 Evin
# 24 Colin
# 25 Marcus
# 26 Thisara
# 27 Alex
# 28 Rilee
# 29 Tom
# 30 Liam
# 31 Aaron
# 32 Mustafizur
# 33 Piyush
# 34 Nathan
# 35 Tim
# 36 Sam
# 37 Andrew
# 38 Yusuf
# 39 Jaydev
# 40 Ashton
# 41 David
# 42 Mushfiqur
# 43 David
# 44 Chris
# 45 Jason
# 46 Lendl
# 47 Sean
# 48 Corey
# 49 Colin
# 50 Dan
# 51 Saqib
# 52 Mohammad
# 53 Ish
# 54 Marchant
# 55 Ben
# 56 Shai
# 57 Dimuth
# 58 Rovman
# 59 Daryl
# 60 Janneman
# 61 Heinrich
# 62 Aiden
# 63 Ravi
# 64 Wanindu
# 65 Wiaan
# 66 Isuru
# 67 Jeevan
# 68 Alex
# 69 Fabian
# 70 Anaru
# 71 Stuart
# 72 Glenn
# 73 Hanuma
# 74 Ben
# 75 Kesrick
# 76 Blair
# 77 Nuwan
# 78 Obed
# 79 Dushmanta
# 80 Jon Jon
# 81 Dasun
# 82 Tabraiz
# 83 Waqar
# 84 Khary
# 85 Fawad
# 86 Qais
# 87 Naveen
# 88 Oshane
# ...

# %%
js
